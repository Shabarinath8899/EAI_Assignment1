# %% [markdown]
# <a href="https://colab.research.google.com/github/Shabarinath8899/EAI_Assignment1/blob/master/Shabarinath_Chandran_Week_3_Lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Shabarinath Chandran
# * EAI6000
# * 03/04/2020

# %% [markdown]
# In this lab we will train a neural network model to classify images of clothing.
#
# This lab uses [tf.keras](https://www.tensorflow.org/guide/keras), a high-level API to build and train models in TensorFlow.

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass
# Out:
# TensorFlow 2.x selected.

# %%
from __future__ import absolute_import, division, print_function, unicode_literals

# TensorFlow and tf.keras
import tensorflow as tf
from tensorflow import keras

# Helper libraries
import numpy as np
import matplotlib.pyplot as plt

print(tf.__version__)
# Out:
# 2.1.0

# %% [markdown]
# ## Import the Fashion MNIST dataset

# %%
from keras.models import Sequential
from keras.layers import Convolution2D
from keras.layers import MaxPooling2D
from keras.layers import Flatten
from keras.layers import Dense
# Out:
# Using TensorFlow backend.

# %%
fashion_mnist = keras.datasets.fashion_mnist

(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()

class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 8192/5148 [===============================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step

# %% [markdown]
# # Examine the dataset size.
# 1. What are the sizes of each image?
# 2. How many categories are there?
# 3. How many images are there in the test and training sets?
# 4. What are the range of values for the images?

# %%
print('Train_images', train_images.shape, train_labels.shape)
print('Test_images', (test_images.shape, test_labels.shape))
# summarize pixel values
print('Train_images', train_images.min(), train_images.max(), train_images.mean(), train_images.std())
print('Test_images', test_images.min(), test_images.max(), test_images.mean(), test_images.std())
# Out:
# Train_images (60000, 28, 28) (60000,)
# Test_images ((10000, 28, 28), (10000,))
# Train_images 0 255 72.94035223214286 90.02118235130519
# Test_images 0 255 73.14656658163265 89.87325907809718

# %% [markdown]
# 1. What are the sizes of each image?
#
#    Each image is of size 28 * 28
#
# 2. How many categories are there?
#
#    There is total 10 categories.
#
# 3. How many images are there in the test and training sets?
#
#    Training data has 60,000 images and est data has 10,000     images.
#
# 4. What are the range of values for the images?
#
#    Range is between 0 to 255.

# %% [markdown]
# Preprocess the data by scaling the pixel values of all images to fall between 0 and 1.

# %%
train_images = train_images / 255.0

test_images = test_images / 255.0

# %% [markdown]
# To verify if the data is in the correct format display the first 10 images from the *training set* and display the class name below each image.

# %%
plt.figure(figsize=(10,10))
for i in range(10):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_images[i], cmap=plt.cm.binary)
    plt.xlabel(class_names[train_labels[i]])
plt.show()

# %% [markdown]
# # Build the model
#
# Using Keras, build a neural network with a single hidden layer consisting of 64 neurons. Remember that you will either have to reshape the image data into 1D vectors, or use a flatten layer at the input.
# 1. Set up the model layers
# 2. Compile the model
# 3. Print the model summary

# %%
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28,28)),
    keras.layers.Dense(64, activation='relu'),
     keras.layers.Dense(10)
])

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            (None, 784)               0
# _________________________________________________________________
# dense (Dense)                (None, 64)                50240
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                650
# =================================================================
# Total params: 50,890
# Trainable params: 50,890
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Train the model
#
# Train the model on the training images for 20 epochs.

# %%
cs = model.fit(train_images, train_labels, epochs=20)
# Out:
# Train on 60000 samples
# Epoch 1/20
# 60000/60000 [==============================] - 5s 89us/sample - loss: 0.5160 - accuracy: 0.8204
# Epoch 2/20
# 60000/60000 [==============================] - 5s 81us/sample - loss: 0.3861 - accuracy: 0.8603
# Epoch 3/20
# 60000/60000 [==============================] - 5s 83us/sample - loss: 0.3510 - accuracy: 0.8729
# Epoch 4/20
# 60000/60000 [==============================] - 5s 78us/sample - loss: 0.3286 - accuracy: 0.8806
# Epoch 5/20
# 60000/60000 [==============================] - 5s 79us/sample - loss: 0.3132 - accuracy: 0.8851
# Epoch 6/20
# 60000/60000 [==============================] - 5s 78us/sample - loss: 0.2992 - accuracy: 0.8892
# Epoch 7/20
# 60000/60000 [==============================] - 5s 76us/sample - loss: 0.2867 - accuracy: 0.8947
# Epoch 8/20
# 60000/60000 [==============================] - 4s 74us/sample - loss: 0.2767 - accuracy: 0.8978
# Epoch 9/20
# 60000/60000 [==============================] - 4s 71us/sample - loss: 0.2685 - accuracy: 0.9009
# Epoch 10/20
# 60000/60000 [==============================] - 4s 70us/sample - loss: 0.2600 - accuracy: 0.9041
# Epoch 11/20
# 60000/60000 [==============================] - 4s 72us/sample - loss: 0.2537 - accuracy: 0.9061
# Epoch 12/20
# 60000/60000 [==============================] - 4s 71us/sample - loss: 0.2464 - accuracy: 0.9083
# Epoch 13/20
# 60000/60000 [==============================] - 4s 72us/sample - loss: 0.2392 - accuracy: 0.9113
# Epoch 14/20
# 60000/60000 [==============================] - 4s 71us/sample - loss: 0.2328 - accuracy: 0.9140
# Epoch 15/20
# 60000/60000 [==============================] - 4s 71us/sample - loss: 0.2287 - accuracy: 0.9147
# Epoch 16/20
# 60000/60000 [==============================] - 5s 75us/sample - loss: 0.2223 - accuracy: 0.9176
# Epoch 17/20
# 60000/60000 [==============================] - 4s 75us/sample - loss: 0.2185 - accuracy: 0.9183
# Epoch 18/20
# 60000/60000 [==============================] - 5s 79us/sample - loss: 0.2131 - accuracy: 0.9196
# Epoch 19/20
# 60000/60000 [==============================] - 5s 79us/sample - loss: 0.2088 - accuracy: 0.9226
# Epoch 20/20
# 60000/60000 [==============================] - 5s 77us/sample - loss: 0.2042 - accuracy: 0.9249

# %% [markdown]
# # Evaluate the accuracy of the model on the test dataset. How does it compare with the training accuracy? Is it likely overfitting or underfitting?

# %%
test_loss, test_acc = model.evaluate(test_images,  test_labels, verbose=2)

print('\nTest accuracy:', test_acc)
# Out:
# 10000/10000 - 0s - loss: 0.3480 - accuracy: 0.8846
#
# Test accuracy: 0.8846

# %%
train_loss, train_acc = model.evaluate(train_images,  train_labels, verbose=2)
print('\nTest accuracy:', train_acc)
# Out:
# 60000/60000 - 2s - loss: 0.1932 - accuracy: 0.9277
#
# Test accuracy: 0.9277

# %% [markdown]
# Accuracy of test data is 0.88 and its really good but the train data has accuracy of 0.92. Hence we can conclude its overfitting.

# %% [markdown]
# ### Make predictions
#
# The outputs layer of the model contains predictions about the classification for each image.

# %%
probability_model = tf.keras.Sequential([model, 
                                         tf.keras.layers.Softmax()])
class_predictions = model.predict_classes(test_images)
prediction_probabilities = probability_model.predict(test_images)

# %%
predictions = probability_model.predict(test_images)

# %%
predictions[0]
# Out:
# array([6.8112391e-09, 1.0219202e-09, 9.8366322e-11, 1.9782186e-12,
#        6.3595138e-08, 1.1119933e-03, 7.8366984e-09, 4.5628091e-03,
#        1.0370737e-06, 9.9432409e-01], dtype=float32)

# %%
prediction_probabilities.shape
# Out:
# (10000, 10)

# %%
class_predictions.shape
# Out:
# (10000,)

# %% [markdown]
# Examine the shape of the variable 'prediction_probabilities'. How is it different from class_predictions? What do the dimensions correspond to?

# %% [markdown]
# Shape of prediction probnability is (10000, 10). while class_prediction has shape of (10000,)

# %% [markdown]
# The following functions plot the image and a bar graph of the predicted probabilities. Using these functions, make a plot of the first 25 test images that were incorrectly classified along with their predicted probabilities. Interpret these images - what sort of images tend to be misclassified?

# %%
def plot_image(i, predictions_array, true_label, img):
  predictions_array, true_label, img = predictions_array, true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img, cmap=plt.cm.binary)

  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("{} {:2.0f}% ({})".format(class_names[predicted_label],
                                100*np.max(predictions_array),
                                class_names[true_label]),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
  predictions_array, true_label = predictions_array, true_label[i]
  plt.grid(False)
  plt.xticks(range(10))
  plt.yticks([])
  thisplot = plt.bar(range(10), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label].set_color('blue')

# %%
misclassified = np.where(class_predictions != test_labels)
misclassified
# Out:
# (array([  12,   17,   23, ..., 9985, 9989, 9991]),)

# %%
count = 0
for i in range(len(test_labels)):
  if np.argmax(prediction_probabilities[i]) != test_labels[i]:
    count += 1
    if count <= 25:
      num_rows = 5
      num_cols = 5
      num_images = num_rows*num_cols
      plt.figure(figsize=(2*2*num_cols, 2*num_rows))
      plt.subplot(num_rows, 2*num_cols+2, 2*count+1)
      plot_image(i, prediction_probabilities[i], test_labels, test_images)
      plt.subplot(num_rows, 2*num_cols+2, 2*count+2)
      plot_value_array(i, prediction_probabilities[i], test_labels)
      plt.tight_layout()
      plt.show()

# %% [markdown]
# *  We can see that similar looking items has more chances of being missclassified. As shirts and pullovers looks alike.

# %% [markdown]
# # Plot a confusion matrix of the predictions. Which misclassifications are the most common?

# %%
from sklearn.metrics import confusion_matrix 
from sklearn.metrics import accuracy_score 
from sklearn.metrics import classification_report

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels,class_predictions)
fig, ax = plt.subplots()
im = ax.imshow(cm)
ax.set_xticks(np.arange(10)), ax.set_yticks(np.arange(10))
ax.set_xticklabels(list(class_names), rotation=45, ha="right")
ax.set_yticklabels(list(class_names))
ax.set_ylabel('True')
ax.set_xlabel('Predicted')
for i in range(100):
    ax.text(int(i/10),i%10,cm[i%10,int(i/10)], ha="center", va="center", color="w")

# %% [markdown]
# Most common misclassifion is for shirts classified as pullovers and shirts classified as t-shirt or tops.
